# %%
import urllib.request
import json
import pandas as pd
import numpy as np
contents = urllib.request.urlopen("https://www.romexchange.com/api").read()

data = contents.decode("utf-8")
print(data)
# Out:
# [{"name":"2019 August Premium","type":14,"image":null,"global_sea_diff":-5.6,"global":{"week":{"data":[{"snap":false,"price":5096874,"time":"2019-10-22T07:49:54Z"},{"snap":false,"price":5733897,"time":"2019-10-26T07:50:28Z"},{"snap":false,"price":5851145,"time":"2019-10-27T07:44:28Z"},{"snap":false,"price":5915606,"time":"2019-10-29T07:52:04Z"}],"change":16.1},"latest":5915606,"latest_time":"2019-10-29T07:52:04Z"},"sea":{"week":{"data":[{"snap":false,"price":5277589,"time":"2019-10-23T10:42:33Z"},{"snap":false,"price":5271215,"time":"2019-10-24T10:36:10Z"},{"snap":false,"price":5007540,"time":"2019-10-25T10:29:52Z"},{"snap":false,"price":5010214,"time":"2019-10-26T10:15:16Z"},{"snap":false,"price":5115887,"time":"2019-10-27T10:50:15Z"},{"snap":false,"price":5568017,"time":"2019-10-28T10:32:22Z"},{"snap":false,"price":5584876,"time":"2019-10-29T11:03:03Z"}],"change":5.8},"latest":5584876,"latest_time":"2019-10-29T11:03:03Z"}},{"name":"2019 Bandana","type":16,"image":null,"global_sea_d
# ...
