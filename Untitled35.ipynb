# %%
# Out:
# <Timer(Thread-6, started 7228)>
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "c:\users\developer\desktop\leix\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "c:\users\developer\desktop\leix\lib\threading.py", line 1158, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-870eac04bb9b>", line 7, in func_wrapper
#     func()
# TypeError: 'NoneType' object is not callable
#
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "c:\users\developer\desktop\leix\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "c:\users\developer\desktop\leix\lib\threading.py", line 1158, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-870eac04bb9b>", line 7, in func_wrapper
#     func()
# TypeError: 'NoneType' object is not callable
#
# Exception in thread Thread-8:
# Traceback (most recent call last):
# ...
