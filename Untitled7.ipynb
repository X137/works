# %%
from bs4 import BeautifulSoup
import requests
card_pages =1
for card_page in range(1, card_pages+1):
    url = "http://www.roguard.net/db/cards/?page={}".format(card_page)
    response = requests.get(url)
    content = BeautifulSoup(response.content, "html.parser")

    paragraphs = content.find_all("tr")
    # print(paragraphs)
    for i in range(0, len(paragraphs)):
        item = {}
        item['name'] = paragraphs[i].find_all(
            "td")[1].find_all("div")[0].get_text()
        item['effect'] = paragraphs[i].find_all(
            "td")[2].find_all("div")[1].get_text().split('\n')
        item['loot_effect'] = paragraphs[i].find_all(
            "td")[2].find_all("div")[3].get_text().split('\n')
        print(item)
# Out:
# {'name': 'Abysmal Knight Card', 'effect': ['Damage to Boss monster ＋10%'], 'loot_effect': ['Damage to Boss monster ＋1%']}
# {'name': 'Agav Card', 'effect': ['M.Atk ＋5%', '', 'When the wearer is a Mage, M.Atk ＋3%, Max HP ＋300, Max SP ＋150'], 'loot_effect': ['Max HP ＋28']}
# {'name': 'Air Wave Card', 'effect': ['[Investigate] CD reduced by 1s'], 'loot_effect': ['Atk ＋8']}
# {'name': 'Alarm Card', 'effect': ['Max HP ＋300', 'VIT ＋1', 'INT ＋1'], 'loot_effect': ['Max HP ＋12']}
# {'name': 'Alice Card', 'effect': ['Damage from Boss monsters -15%'], 'loot_effect': ['Damage from Boss monsters -2%']}
# {'name': 'Anacondaq Card', 'effect': ['Dmg to Poison monsters ＋15%'], 'loot_effect': ['Max HP ＋28']}
# {'name': 'Ancient Clock Card', 'effect': ['Str ＋2', 'INT ＋1', 'Max HP ＋1%'], 'loot_effect': ['Max HP ＋12']}
# {'name': 'Andre Card', 'effect': ['Atk ＋10'], 'loot_effect': ['Atk ＋3']}
# {'name': 'Andre★Card', 'effect': ['Pen. ＋3%', 'Ignores Def ＋3% when STR or DEX reaches 225'], 'loot_effect': ['Def ＋6']}
# {'name': 'Angeling Card', 'effect': ["Turn the armor's element into Holy"], 'loot_effect': ['M.Atk ＋20']}
# {'name': 'Anolian Card', 'effect': ['When suffering Dam, There is a 3% chance to cause: Agi ＋5, Dex ＋5; this effect lasts 2 minutes.'], 'loot_effect': ['Agi ＋1']}
# {'name': 'Anubis Card', 'effect': ['Angel monsters Dmg Taken -30%'], 'loot_effect': ['Max HP ＋84']}
# {'name': 'Aqua Elemental Card', 'effect': ['Water Dmg Taken -15%', 'Dmg to Water Monsters ＋5%'], 'loot_effect': ['Max HP ＋28']}
# {'name': 'Arc Angeling Card', 'effect': ['Max HP ＋10%'], 'loot_effect': ['Def ＋1%, MDef ＋1%']}
# {'name': 'Archer Skeleton Card', 'effect': ['Melee Atk ＋5%', '', 'Ranged Atk ＋10%'], 'loot_effect': ['Atk ＋8']}
# {'name': 'Archer Skeleton★Card', 'effect': ['Str ＋2', 'Atk ＋5%'], 'loot_effect': ['M.Atk ＋8']}
# {'name': 'Argiope Card', 'effect': ["Turn the armor's element into Poison", 'Def ＋20'], 'loot_effect': ['Def ＋4']}
# {'name': 'Asuka Card', 'effect': ['Def ＋4%', 'Dmg Reduc. ＋4%'], 'loot_effect': ['MDef ＋2, Max HP ＋30']}
# {'name': 'Atroce Card', 'effect': ['auto attack has a 5% chance to trigger amazing speed (Attack Spd ＋20%; this effect lasts 10 seconds)'], 'loot_effect': ['Atk ＋12']}
# {'name': 'Baby Desert Wolf Card', 'effect': ['Dmg to Demi-Human ＋3%'], 'loot_effect': ['Dmg to Demi-Human ＋1%']}

# %%
from bs4 import BeautifulSoup
import requests
import re
card_pages =1

# url = "http://www.roguard.net/db/items/?page={}".format(card_page)

target = "jellopy"
url = "https://www.roguard.net/db/items/?search=" + target
response = requests.get(url)
content = BeautifulSoup(response.content, "html.parser")

paragraphs = content.find_all("tr")
new_href = str(paragraphs[0].find_all("a"))
print(new_href)
targetId = int(re.search(r'\d+', new_href).group())
print(targetId)

url = "https://www.roguard.net/db/items/" + str(targetId)
response = requests.get(url)
content = BeautifulSoup(response.content, "html.parser")

# print(content)

# print(paragraphs)
#     for i in range(0, len(paragraphs)):
#         item = {}
#         item['name'] = paragraphs[i].find_all(
#             "td")[1].find_all("div")[0].get_text()
#         item['effect'] = paragraphs[i].find_all(
#             "td")[2].find_all("div")[1].get_text().split('\n')
#         item['loot_effect'] = paragraphs[i].find_all(
#             "td")[2].find_all("div")[3].get_text().split('\n')
#         print(item)

url = "https://www.romexchange.com/"
response = requests.get(url)
content = BeautifulSoup(response.content, "html.parser")
print(content)
# Out:
# [<a href="/db/items/52101/">Jellopy</a>]
# 52101
# <head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body>
