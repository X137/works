# %%
import requests 
from bs4 import BeautifulSoup





url = "https://www.google.com/search?" + "q=" + "Jellopy price ragnarok roguard"
content = requests.get(url)

content2 = requests.get("https://www.roguard.net/db/items/52101/")
soup = BeautifulSoup(content2.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <!-- Required meta tags -->
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <title>
#    Jellopy - Item Database - ROGuard - Ragnarok M: Eternal Love Database
#   </title>
#   <meta content="Crystal made from monster parts. I wonder what you can make with it?" name="description">
#    <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <meta content="Jellopy - Item Database - ROGuard - Ragnarok M: Eternal Love Database" property="og:title">
#     <meta content="website" property="og:type"/>
#     <meta content="http://www.roguard.net/db/items/52101/" property="og:url"/>
#     <meta content="//www.roguard.net/content/img/icons/items/item_52101.png" property="og:image"/>
#     <meta content="Crystal made from monster parts. I wonder what you can make with it?" property="og:description"/>
#     <!-- Font Awesome -->
# ...
